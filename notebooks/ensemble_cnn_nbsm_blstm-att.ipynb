# %%
import pandas as pd

# %%
nbsvm = pd.read_csv('../submissions/nbsvm-baseline.csv').set_index('id')
#blstm = pd.read_csv('../submissions/bstlm_attention.csv')
cnn = pd.read_csv('../submissions/cnn.csv').set_index('id')

# %%
preds = (3*cnn + 2*nbsvm)/5
preds = preds.reset_index()

# %%
preds.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.939393      0.075080  0.781593  0.012574  0.691383
# 1  0000247867823ef7  0.009400      0.000912  0.003611  0.000176  0.004285
# 2  00013b17ad220c46  0.008499      0.000645  0.003720  0.000147  0.003413
# 3  00017563c3f7919a  0.001823      0.000388  0.001246  0.000272  0.001443
# 4  00017695ad8997eb  0.013800      0.000504  0.002390  0.000194  0.002804
#
#    identity_hate
# 0       0.151261
# 1       0.000551
# 2       0.000425
# 3       0.000362
# 4       0.000439

# %%
#preds = (2*nbsvm + 4*blstm + 3*cnn)/9

# %%
preds.to_csv('../submissions/ensemble_cnn_nbsvm.csv', index=False)

# %%
pd.read_csv('../submissions/ensemble_cnn_nbsvm.csv')
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  0.939393      0.075080  0.781593  0.012574
# 1       0000247867823ef7  0.009400      0.000912  0.003611  0.000176
# 2       00013b17ad220c46  0.008499      0.000645  0.003720  0.000147
# 3       00017563c3f7919a  0.001823      0.000388  0.001246  0.000272
# 4       00017695ad8997eb  0.013800      0.000504  0.002390  0.000194
# 5       0001ea8717f6de06  0.003946      0.000374  0.001778  0.000175
# 6       00024115d4cbde0f  0.001013      0.000334  0.000976  0.000155
# 7       000247e83dcc1211  0.111639      0.000516  0.016198  0.000282
# 8       00025358d4737918  0.029559      0.000232  0.004192  0.000151
# 9       00026d1092fe71cc  0.004036      0.000497  0.001798  0.000159
# 10      0002eadc3b301559  0.291746      0.000321  0.049621  0.000199
# 11      0002f87b16116a7f  0.088696      0.000286  0.010522  0.000285
# 12      0003806b11932181  0.004182      0.000338  0.001242  0.000119
# ...
