# %%
import pandas as pd

# %%
nbsvm = pd.read_csv('../submissions/nbsvm-baseline.csv').set_index('id')
blstm = pd.read_csv('../submissions/blstm_attention.csv').set_index('id')
cnn = pd.read_csv('../submissions/cnn.csv').set_index('id')

# %%
preds = (5*cnn + 3*nbsvm + 2*blstm)/10
preds = preds.reset_index()

# %%
preds.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.949449      0.137852  0.815545  0.021471  0.726183
# 1  0000247867823ef7  0.007646      0.000689  0.002782  0.000138  0.003287
# 2  00013b17ad220c46  0.006722      0.000491  0.002831  0.000122  0.002626
# 3  00017563c3f7919a  0.001403      0.000292  0.000938  0.000206  0.001086
# 4  00017695ad8997eb  0.011743      0.000391  0.001933  0.000165  0.002231
#
#    identity_hate
# 0       0.250528
# 1       0.000424
# 2       0.000331
# 3       0.000274
# 4       0.000353

# %%
#preds = (2*nbsvm + 4*blstm + 3*cnn)/9

# %%
preds.to_csv('../submissions/ensemble_cnn_nbsvm_blstm.csv', index=False)

# %%
pd.read_csv('../submissions/ensemble_cnn_nbsvm_blstm.csv')
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  0.949449      0.137852  0.815545  0.021471
# 1       0000247867823ef7  0.007646      0.000689  0.002782  0.000138
# 2       00013b17ad220c46  0.006722      0.000491  0.002831  0.000122
# 3       00017563c3f7919a  0.001403      0.000292  0.000938  0.000206
# 4       00017695ad8997eb  0.011743      0.000391  0.001933  0.000165
# 5       0001ea8717f6de06  0.003140      0.000283  0.001369  0.000139
# 6       00024115d4cbde0f  0.001171      0.000254  0.000760  0.000125
# 7       000247e83dcc1211  0.134481      0.000420  0.014266  0.000223
# 8       00025358d4737918  0.033683      0.000189  0.003846  0.000121
# 9       00026d1092fe71cc  0.003163      0.000374  0.001365  0.000125
# 10      0002eadc3b301559  0.364862      0.000587  0.091633  0.000171
# 11      0002f87b16116a7f  0.090851      0.000261  0.009776  0.000291
# 12      0003806b11932181  0.003237      0.000254  0.000937  0.000090
# ...

# %%
a = pd.read_csv('../submissions/ensemble_cnn_nbsvm_blstm.csv')

# %%
a.iloc[134754]
# Out:
# id               e14a8252cc994d4c
# toxic                    0.112278
# severe_toxic          0.000561351
# obscene                  0.014717
# threat                 0.00152685
# insult                  0.0167861
# identity_hate          0.00115516
# Name: 134754, dtype: object
